# %%
import matplotlib.pyplot as plt

x = [0,5,8,11,12,15,18,22,25,28,32,36,38,39,43,44,45,46,49,50,51]
y = [0.05, 0.06, 0.08, 0.10, 0.13, 0.15, 0.20, 0.22, 0.25, 0.29, 0.32, 0.33, 0.34, 0.37, 0.39, 0.41, 0.42, 0.44, 0.45, 0.46, 0.49 ]

plt.scatter(x, y)
plt.show()

# %%
import numpy as np
barx = np.mean(x)
bary = np.mean(y)
#es la varianza muestral
print(barx, bary)
# Out:
# 29.38095238095238 0.2833333333333334

# %%
varx = np.var(x, ddof=1) #la varianza muestral
covxy = np.cov(x,y, ddof=1) #la covarianza muestral

print(varx, covxy)
# Out:
# 269.04761904761904 [[2.69047619e+02 2.36516667e+00]
#  [2.36516667e+00 2.09633333e-02]]

# %%
print(varx)
# Out:
# 269.04761904761904

# %%
covxy = covxy[0,1]
covxy
# Out:
# 2.365166666666667

# %%
beta1 = covxy/varx
beta0 = bary-beta1*barx
#beta0 es el intercepto y el 1 es la pendiente que es negativa, los puntos tienen tendencia negativa
#nuestra recta de regresión para esos datos quedaría --> y= 103.1 - 1.7 x
print(beta0, beta1)
# Out:
# 0.025048761061946923 0.008790884955752214

# %%
import matplotlib.pyplot as plt
from scipy import stats


slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x)) 

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
slope, intercept
# Out:
# (0.008790884955752214, 0.025048761061946923)

# %%
r
# Out:
# 0.9959029140154058

# %%
s = myfunc(53)
s
# Out:
# 0.49096566371681427

# %%
## PARTE 2

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('top50.csv', encoding='ISO-8859-1')
data
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
data.groupby("Beats.Per.Minute")[["Popularity"]].mean()
# Out:
#                   Popularity
# Beats.Per.Minute
# 85                 87.000000
# 88                 88.000000
# 90                 91.000000
# 92                 87.000000
# 93                 85.666667
# 94                 91.000000
# 95                 80.000000
# 96                 87.750000
# 98                 86.666667
# 100                88.500000
# 101                92.000000
# 102                84.000000
# 104                88.000000
# 105                92.000000
# 110                88.000000
# 111                90.000000
# 114                89.000000
# 117                79.000000
# 124                80.500000
# 130                88.000000
# 135                92.000000
# 136                85.500000
# 138                80.000000
# 140                89.000000
# 150                94.000000
# 152                87.000000
# 154                91.000000
# 158                91.000000
# 176                89.800000
# 180                92.000000
# ...
