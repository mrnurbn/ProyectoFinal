# %% [markdown]
# ## Examen Base de datos
# ### Mariana Urbina
# ### Cecilia Zaldívar
# 23 DE OCTUBRE 2022

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('top50.csv', encoding='ISO-8859-1')
data
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# ...

# %% [markdown]
# 1. MUESTREN UN DATAFRAME CON LAS 5 CANCIONES MÁS POPULARES

# %%
data.groupby("Track.Name")[["Popularity"]].mean().sort_values(['Popularity'], ascending= False).head()
# Out:
#                              Popularity
# Track.Name
# bad guy                            95.0
# Goodbyes (Feat. Young Thug)        94.0
# Callaita                           93.0
# Ransom                             92.0
# China                              92.0

# %% [markdown]
# 2.1 ¿CUALES CANCIONES ENTRE 120 Y 250 SEGUNDOS DE DURACIÓN TUVIERON POPULARIDAD BAJA A PESAR DE TENER NIVELES DE "BAILABILIDAD" MAXIMOS?

# %%
#120-250 segundos con Popularidad baja 
df_bailabilidad_pop = data[(data["Length."]>=120) & (data["Length."]<250) & ((data["Popularity"]< 88))][["Track.Name", "Artist.Name","Popularity", "Danceability"]]
df_bailabilidad_pop
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 8                               Old Town Road - Remix         Lil Nas X
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# 25                                If I Can't Have You      Shawn Mendes
# 26                                       Dance Monkey       Tones and I
# 30                                           Takeaway  The Chainsmokers
# 37                     Antisocial (with Travis Scott)        Ed Sheeran
# 38                                             Sucker    Jonas Brothers
# 39  fuck, i'm lonely (with Anne-Marie) - from 13 ...              Lauv
# ...

# %%
#Niveles máximos de bailabilidad
max_bailabilidad = data["Danceability"] > data["Danceability"].quantile(0.95)
max_bailabilidad
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44     True
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Danceability, dtype: bool

# %%
data[(data["Length."]>=120) & (data["Length."]<250) & ((data["Popularity"] < 88)) & (data["Danceability"] > data["Danceability"].quantile(0.95))]
# Out:
#     Unnamed: 0             Track.Name Artist.Name        Genre  \
# 8            9  Old Town Road - Remix   Lil Nas X  country rap
# 43          44                   Talk      Khalid          pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 8                136      62            88              -6        11
# 43               136      40            90              -9         6
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 8         64      157               5            10          87
# 43        35      198               5            13          84

# %% [markdown]
# 2.2 ¿CUALES CANCIONES ENTRE 120 Y 250 SEGUNDOS DE DURACIÓN TUVIERON POPULARIDAD ALTA A PESAR DE TENER NIVELES DE "BAILABILIDAD" MÍNIMOS?

# %%
df_bailabilidad_min = data[(data["Length."]>=120) & (data["Length."]<250) & ((data["Popularity"] > 88)) & (data["Danceability"] > data["Danceability"].quantile(0.25) )  ]
df_bailabilidad_min
# Out:
#     Unnamed: 0                                     Track.Name    Artist.Name  \
# 6            7                                         Ransom      Lil Tecca
# 9           10                                        bad guy  Billie Eilish
# 14          15       Money In The Grave (Drake ft. Rick Ross)          Drake
# 16          17                                     LA CANCIÓN       J Balvin
# 17          18  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 19          20                                    Truth Hurts          Lizzo
# 20          21                            Piece Of Your Heart         MEDUZA
# 27          28                                       It's You      Ali Gatie
# 28          29                                      Con Calma   Daddy Yankee
# 31          32                                        7 rings  Ariana Grande
# 32          33                              0.958333333333333         Maluma
# ...

# %% [markdown]
# 3. DE TU DATAFRAME DATA ELIMINQ LA COLUMNA SIN NOMBRE Y CALCULA LA MEDIA Y VARIANZA DE BEATS POR MINUTO. MUESTRENLO EN UN DATAFRAME

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
mean = data['Beats.Per.Minute'].mean()
mean
# Out:
# 120.06

# %%
varianza = data['Beats.Per.Minute'].var()
varianza
# Out:
# 954.7106122448979

# %%
BeatsPerMinutes = {'Beats.Per.Minute':[mean],
                   'Beats.Per.Minute':[varianza]}

# %%
columns = ['Media', 'Varianza']
index = ['Beats.Per.minute']

# %%
pd.DataFrame({'Media': [mean],'Varianza':[varianza]}, index= index)
# Out:
#                    Media    Varianza
# Beats.Per.minute  120.06  954.710612

# %% [markdown]
# 4. CUÁLES SON LOS 10 GENEROS MÁS ESCUCHADOS

# %%
top10genres = data.groupby('Genre')[['Popularity']].mean().sort_values(['Popularity'], ascending=False).head(10)
top10genres
# Out:
#                   Popularity
# Genre
# dfw rap            92.500000
# trap music         92.000000
# electropop         92.000000
# reggaeton          91.000000
# pop house          91.000000
# escape room        91.000000
# latin              89.800000
# canadian hip hop   89.666667
# panamanian pop     89.000000
# atl hip hop        89.000000

# %% [markdown]
# 5) CUÁL FUE EL ARTISTA MÁS ESCUCHADO

# %%
data.groupby('Artist.Name')[['Popularity']].mean().sort_values(['Popularity'],ascending=False).head(1)
# Out:
#              Popularity
# Artist.Name
# Bad Bunny          93.0

# %% [markdown]
# GRÁFICAS

# %%
#En esta gráfica de barras podemos observar cuales son los top10 generos musicales 
#con la popularidad que tienen
top10genres.plot(kind="bar" )

# %%
#120-250 segundos con Popularidad baja
sns.boxplot(x=df_bailabilidad_pop['Popularity'])

# %%
#CANCIONES ENTRE 120 Y 250 SEGUNDOS DE DURACIÓN TUVIERON POPULARIDAD ALTA A PESAR DE TENER NIVELES DE "BAILABILIDAD" MÍNIMOS
sns.boxplot(x=df_bailabilidad_min['Popularity'])

# %%
#Histograma de las top 5 canciones de acuerdo con la popularidad 
top5.plot.hist(bins=5)

# %%
#df_plot = data.groupby(by="Track.Name").Danceability.mean().head(10)
df_plot=data.groupby('Track.Name')[['Danceability']].mean().sort_values(['Danceability'],ascending=False).head(10)
df_plot
# Out:
#                                                     Danceability
# Track.Name
# Talk                                                        90.0
# Old Town Road - Remix                                       88.0
# Con Altura                                                  88.0
# Sucker                                                      84.0
# Lalala                                                      84.0
# Money In The Grave (Drake ft. Rick Ross)                    83.0
# Dance Monkey                                                82.0
# Loco Contigo (feat. J. Balvin & Tyga)                       82.0
# No Me Conoce - Remix                                        81.0
# fuck, i'm lonely (with Anne-Marie) - from 13 R...          81.0

# %%
#grafica con las 10 canciones con el promedio de danceability mas alto
df_plot.plot(kind="bar")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### CONCLUSIONES:
# - Podemos observar que el criterio de "Bailabilidad" no es un atributo clave que determina la popularidad pues con el análisis elaborado, se observó que las canciones más populares tenían niveles de bailabilidad mínimos mientras que canciones menos populares, sus niveles de bailabilidad eran los más altos.Por lo tanto, el tener una canción con altos niveles de bailabilidad no asegura que sea de las más populares por lo que los artistas deberían tomar en cuenta otros criterios y que sea más posible que sus canciones sean populares
# - Hay más canciones popularidades con niveles de bailabilidad mínimos que máximos
# - 2 de las 5 canciones más populares son en espàñol y el artista más escuchado durante ese año fue Bad Bunny, quien es latino
# - Con ayuda de la popularidad podemos saber quién fue el artista más escuchado
# - Al analizar estos datos podemos obtener diferentes tipos de información, así como: las canciones más escuchadas, el artista más famoso, la bailabilidad según su popularidad, entre muchos otros datos. Además nos permite hacer análisis con condiciones, tomando varios atributos a la vez para ser capaces de responder distintas preguntas qu epodemos plantear a partir de la base de datos
# - Un análisis exploratorio de datos nos ayuda a ver de diferentes maneras la información, es decir, podemos analizar desde varias perspectivas una información sin necesidad de confirmar forzosamente una hipotesis.
